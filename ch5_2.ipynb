# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def saturation(val): #클램핑함수
  if val> 255:
    return 255
  elif val < 0:
    return 0
  else:
    return val

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/고소영.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)
# Out:
# (720, 1200, 3)
# (720, 1200)
# <PIL.Image.Image image mode=L size=1200x720>

# %%
outimg = cv2.blur(gimg1,(7,7),0)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=1200x720>

# %%
outimg2 = cv2.GaussianBlur(gimg1,(7,7),0)
cv2_imshow(outimg2)
# Out:
# <PIL.Image.Image image mode=L size=1200x720>

# %%
outimg3 = cv2.medianBlur(gimg1,7)
cv2_imshow(outimg3)
# Out:
# <PIL.Image.Image image mode=L size=1200x720>

# %%
outimage = gimg1.copy()
#blurimage= cv2.GaussianBlur(outimage,(7,7),0)
blurimage = cv2.medianBlur(outimage,7)

x=400+50+20+20+15
y=300+20+10
size=20

for h in range(y,y+size):
  for w in range(x, x+size):
    outimage [h][w] = blurimage[h][w]

cv2_imshow(outimage)
# Out:
# <PIL.Image.Image image mode=L size=1200x720>

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')
print(img.shape)
gimg2 = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
print(gimg2.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg2)
# Out:
# (256, 256, 3)
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outimg2 = cv2.GaussianBlur(gimg2,(7,7),1)
cv2_imshow(outimg2)
#고주파필터 이미지
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeimage = cv2.addWeighted(gimg2,1,outimg2,-1,0)
cv2_imshow(edgeimage)
#에지이미지
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
unsharpimage = cv2.addWeighted(gimg2,1,edgeimage,2,0)
cv2_imshow(unsharpimage)
#언샤프이미지
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
#원본 - 평균 필터
kernel3 = np.ones((3,3),np.float32)/9
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
output = cv2.filter2D(gimg2,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3),np.float32)/9
kernel[0][0] = -1/9
kernel[0][1] = -1/9
kernel[0][2] = -1/9
kernel[1][0] = -1/9
kernel[1][1] = 17/9
kernel[1][2] = -1/9
kernel[2][0] = -1/9
kernel[2][1] = -1/9
kernel[2][2] = -1/9

# %%
output3 = cv2.filter2D(gimg2,-1,kernel)
cv2_imshow(output3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
