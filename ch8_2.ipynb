# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/sp_noise.bmp')
print(img.shape)
gimg1 = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)
# Out:
# (256, 256, 3)
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 오프닝

# %% [markdown]
# 흰색 노이즈 삭제

# %%
kernel = np.ones((3,3),np.uint8)
erosion = cv2.erode(gimg1,kernel,iterations = 1)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv2.dilate(erosion,kernel,iterations = 1)
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 검은색 노이즈 삭제

# %%
kernel = np.ones((3,3),np.uint8)
dilate2 = cv2.dilate(gimg1,kernel,iterations = 1)
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3),np.uint8)
opening2 = cv2.erode(dilate2,kernel,iterations = 1)
cv2_imshow(opening2)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 클로징
